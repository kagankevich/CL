# %% [markdown]
# <a href="https://colab.research.google.com/github/kagankevich/CL/blob/master/27Nov2019%20parse_guardian_dz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise: find all news written today on  and parse the content of https://www.theguardian.com/international each of them into a .txt file

# %% [markdown]
# стратегия работы:
#
# 1. используйте код из тетрадки с пары или из этой (здесь то же самое, но в функциях), чтобы получить лист всех ссылок с главной страницы новостного сайта за определенный день (например, за сегодня)
#
# 2. Из листа ссылок сделайте лист со ссылками только на новости (ссылки на катеогрии и другие разделы сайта не нужны)
#
# 3. для каждой ссылки на новость в листе ссылок:
#     3.1. пройдите по ссылке
#     3.2. из этой веб-странички вытащите текст новости + ее заголовок
#     3.3. запишите в отдельный .txt файл
#
# 4. сохраните файлы в папку

# %%
import requests
from bs4 import BeautifulSoup as bs
import datetime as dt
import re
import os

# %%
def parsing_pipe(url):
    req = requests.get(url)
    content = req.content
    soup = bs(content, 'html.parser')
    return soup

def get_today_date():
    today = dt.date.today()
    return today.strftime("%Y/%b/%d")
    #https://docs.python.org/2/library/datetime.html#strftime-strptime-behavior for strftime format explanation
    
def parse_link(soup):
    todaynews = []
    listlinks = soup.find_all("a", href = True)
    for link in listlinks:
        if re.search(get_today_date(),link["href"],re.I) != None:
            todaynews.append(link["href"])
    return set(todaynews)

# %%
#url = "https://www.theguardian.com/uk-news"
url = "https://www.theguardian.com/international"
pagecontent = parsing_pipe(url)
#print(pagecontent)
pagelist = parse_link(pagecontent)
print(pagelist)
# Out:
# {'https://www.theguardian.com/sport/blog/2019/dec/02/anthony-joshua-saudi-arabia', 'https://www.theguardian.com/music/2019/dec/02/the-kacey-musgraves-christmas-show-review-amazon-prime-video-lana-del-rey', 'https://www.theguardian.com/music/2019/dec/02/liam-payne-on-life-after-one-direction-it-was-touch-and-go-i-was-slowly-losing-the-plot', 'https://www.theguardian.com/news/2019/dec/02/climate-crisis-what-is-cop-and-can-it-save-the-world', 'https://www.theguardian.com/world/2019/dec/02/dead-french-floods-as-rescue-helicopter-crashes-marsellie-var-riviera', 'https://www.theguardian.com/news/ng-interactive/2019/dec/02/open-water-lives-of-three-greenlanders-climate-crisis', 'https://www.theguardian.com/cities/2019/dec/02/big-brother-is-watching-chinese-city-with-26m-cameras-is-worlds-most-heavily-surveilled', 'https://www.theguardian.com/us-news/2019/dec/02/impeachment-inquiry-trump-and-his-lawyers-refuse-to-attend-unfair-hearing', 'https://www.theguardian.com/commentisfree/2019/dec/02/labour-red-wall-brexit-progressive-industrial-england', 'https://www.theguardian.com/world/2019/dec/02/markets-buoyed-by-china-economic-data-as-clouds-remain-over-trade-talks', 'https://www.theguardian.com/world/2019/dec/02/cruise-company-apologises-after-staff-pose-as-maori-for-traditional-welcome', 'https://www.theguardian.com/education/2019/dec/02/school-surveillance-us-schools-safety-shootings', 'https://www.theguardian.com/world/2019/dec/02/amazon-pulls-disturbing-christmas-ornaments-bearing-images-of-auschwitz', 'https://www.theguardian.com/artanddesign/2019/dec/02/caught-in-the-crush-are-our-galleries-now-hopelessly-overcrowded', 'https://www.theguardian.com/education/2019/dec/02/from-dog-petting-to-desk-yoga-do-wellbeing-weeks-make-university-less-stressful', 'https://www.theguardian.com/film/2019/dec/02/martin-scorsese-the-irishman-dont-watch-on-phone-netflix', 'https://www.theguardian.com/sport/2019/dec/02/new-zealand-england-second-test-day-four-match-report', 'https://www.theguardian.com/world/2019/dec/02/kim-jong-un-north-korea-debuts-leather-look-as-he-inspects-missile-test', 'https://www.theguardian.com/environment/2019/dec/02/coal-power-becoming-uninsurable-as-firms-refuse-cover', 'https://www.theguardian.com/us-news/2019/dec/02/joe-biden-student-loan-debt-2005-act-2020', 'https://www.theguardian.com/australia-news/2019/dec/02/tony-abbott-filmed-leaving-the-prison-where-cardinal-george-pell-is-being-held', 'https://www.theguardian.com/politics/live/2019/dec/02/general-election-swinson-condemns-johnson-over-trump-friendship-ahead-of-london-visit-live', 'https://www.theguardian.com/environment/2019/dec/02/boris-johnson-urged-to-challenge-trump-on-climate-denial', 'https://www.theguardian.com/commentisfree/2019/dec/02/big-tech-social-remedies-public-ownership-facebook-google', 'https://www.theguardian.com/commentisfree/2019/dec/02/ditch-harmful-myth-noble-hunter-gatherer', 'https://www.theguardian.com/environment/2019/dec/02/migration-v-climate-europes-new-political-divide', 'https://www.theguardian.com/sport/2019/dec/02/david-warner-triple-century-pakistan-giant-feat-dull-game', 'https://www.theguardian.com/commentisfree/2019/dec/02/clive-james-jonathan-miller-funny-tv-intellectuals', 'https://www.theguardian.com/lifeandstyle/gallery/2019/dec/02/the-hollywood-christmas-parade-2019-in-pictures', 'https://www.theguardian.com/world/2019/dec/02/venice-rejects-autonomous-rule-referendum-low-turnout-italy', 'https://www.theguardian.com/sport/2019/dec/02/nathan-lyon-five-fer-australia-thrash-pakistan-innings-48-runs-cricket', 'https://www.theguardian.com/business/2019/dec/02/ted-baker-shares-fall-fashion-chain', 'https://www.theguardian.com/film/shortcuts/2019/dec/02/et-go-home-spielberg-alien-shouldnt-flog-wifi', 'https://www.theguardian.com/football/2019/dec/02/liverpool-pep-lijnders-jurgen-klopp-assistant-paddle-tennis-james-milner', 'https://www.theguardian.com/science/2019/dec/02/can-you-solve-it-smart-as-a-box-of-frogs', 'https://www.t ...

# %%
def parse_and_write_article(url, path):
    pagesoup = parsing_pipe(url)
    title = pagesoup.find("h1").get_text()
    text = " ".join([i.get_text() for i in pagesoup.find_all("p")])
    
    with open(path + os.sep + url.rsplit("/", 1)[1] + ".txt", "w+", encoding = "utf-8") as f:
        f.write(title + "\n" + text)

# %%
path = "." + os.sep + dt.date.today().strftime("%Y%m%d")
try:
    os.mkdir(path)
except:
    pass
i = 0
for link in pagelist:
    #pagesoup = parse_and_write_article(link, path)
    print(link)
    pagesoup = parsing_pipe(link)
    try: 
      title = pagesoup.find("h1").get_text()
    except:
      pass
    print(title)
    text = " ".join([i.get_text() for i in pagesoup.find_all("p")])
    
    with open(path + os.sep + url.rsplit("/", 1)[1] + ".txt", "w+", encoding = "utf-8") as f:
      f.write(title + "\n" + text)
    i = i + 1

print(i)
#
# Kim Jong-un steps out of grandfather's sartorial shadow with trench coat look
#
# https://www.theguardian.com/environment/2019/dec/02/coal-power-becoming-uninsurable-as-firms-refuse-cover
#
# Coal power becoming 'uninsurable' as firms refuse cover
#
# https://www.theguardian.com/us-news/2019/dec/02/joe-biden-student-loan-debt-2005-act-2020
#
# How Biden helped create the student debt problem he now promises to fix
#
# https://www.theguardian.com/australia-news/2019/dec/02/tony-abbott-filmed-leaving-the-prison-where-cardinal-george-pell-is-being-held
#
# Tony Abbott filmed leaving the prison where Cardinal George Pell is being held
#
# https://www.theguardian.com/politics/live/2019/dec/02/general-election-swinson-condemns-johnson-over-trump-friendship-ahead-of-london-visit-live
# General election: Council tax more likely to go up under Tories than Labour, IFS suggests – live news
# https://www.theguardian.com/environment/2019/dec/02/boris-johnson-urged-to-challenge-trump-on-climate-denial
#
# Boris Johnson urged to challenge Trump on climate denial
#
# https://www.theguardian.com/commentisfree/2019/dec/02/big-tech-social-remedies-public-ownership-facebook-google
#
# Of course Facebook and Google want to ‘solve’ social problems. They’re hungry for our data
#
# https://www.theguardian.com/commentisfree/2019/dec/02/ditch-harmful-myth-noble-hunter-gatherer
#
# Time to ditch the harmful myth of the ‘noble’ hunter-gatherer
#
# https://www.theguardian.com/environment/2019/dec/02/migration-v-climate-europes-new-political-divide
#
# Migration v climate: Europe's new political divide
#
# https://www.theguardian.com/sport/2019/dec/02/david-warner-triple-century-pakistan-giant-feat-dull-game
#
# Like those of greats before him, David Warner's triple century was a giant feat in a dull game
#
# https://www.theguardian.com/commentisfree/2019/dec/02/clive-james-jonathan-miller-funny-tv-intellectuals
#
# Clive James and Jonathan Miller had confidence in the wits of their viewers
#
# https://www.theguardian.com/lifeandstyle/gallery/2019/dec/02/the-hollywood-christmas-parade-2019-in-pictures
#
# The Hollywood Christmas Parade 2019 - in pictures
#
# https://www.theguardian.com/world/2019/dec/02/venice-rejects-autonomous-rule-referendum-low-turnout-italy
#
# Venice rejects autonomous rule with poll turnout of just 21%
#
# https://www.theguardian.com/sport/2019/dec/02/nathan-lyon-five-fer-australia-thrash-pakistan-innings-48-runs-cricket
#
# Nathan Lyon takes five-fer as Australia thrash Pakistan by innings and 48 runs
#
# https://www.theguardian.com/business/2019/dec/02/ted-baker-shares-fall-fashion-chain
#
# Ted Baker shares fall after it warns of £25m balance sheet error
#
# https://www.theguardian.com/film/shortcuts/2019/dec/02/et-go-home-spielberg-alien-shouldnt-flog-wifi
#
# ET go home: why Spielberg’s alien shouldn’t be flogging wifi
#
# https://www.theguardian.com/football/2019/dec/02/liverpool-pep-lijnders-jurgen-klopp-assistant-paddle-tennis-james-milner
#
# Liverpool’s Pep Lijnders: ‘Our identity is intensity. It comes back in every drill’
#
# https://www.theguardian.com/science/2019/dec/02/can-you-solve-it-smart-as-a-box-of-frogs
#
# Can you solve it? Smart as a box of frogs
#
# https://www.theguardian.com/world/2019/dec/02/monday-briefing-anger-as-london-bridge-attack-made-political
# Monday briefing: Anger as London Bridge attack made political
